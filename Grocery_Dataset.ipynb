# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\admin\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
df=pd.read_csv('GroceryDataset.csv')

# %%
df
# Out:
#            Sub Category     Price     Discount  \
# 0     Bakery & Desserts   $56.99   No Discount
# 1     Bakery & Desserts  $159.99   No Discount
# 2     Bakery & Desserts   $44.99   No Discount
# 3     Bakery & Desserts   $39.99   No Discount
# 4     Bakery & Desserts   $59.99   No Discount
# ...                 ...       ...          ...
# 1752             Snacks   $23.99   No Discount
# 1753             Snacks   $49.99   No Discount
# 1754             Snacks   $22.99   No Discount
# 1755             Snacks   $17.49   No Discount
# 1756             Snacks   $21.99   No Discount
#
#                                                Rating  \
# 0      Rated 4.3 out of 5 stars based on 265 reviews.
# 1          Rated 5 out of 5 stars based on 1 reviews.
# 2      Rated 4.1 out of 5 stars based on 441 reviews.
# 3     Rated 4.7 out of 5 stars based on 9459 reviews.
# 4      Rated 4.5 out of 5 stars based on 758 reviews.
# ...                                               ...
# ...

# %%
df.tail()
# Out:
#      Sub Category    Price     Discount Rating  \
# 1752       Snacks  $23.99   No Discount    NaN
# 1753       Snacks  $49.99   No Discount    NaN
# 1754       Snacks  $22.99   No Discount    NaN
# 1755       Snacks  $17.49   No Discount    NaN
# 1756       Snacks  $21.99   No Discount    NaN
#
#                                                   Title Currency  \
# 1752  Oberto Thin Style Smoked Sausage Stick, Cockta...        $
# 1753        Cheetos Crunchy, Original, 2.1 oz, 64-count        $
# 1754  Sabritas Chile & Limon Mix, Variety Pack, 30-c...        $
# 1755             Fruit Roll-Ups, Variety Pack, 72-count        $
# 1756  Takis, Rolled Tortilla Chips, Intense Nacho, 1...        $
#
#                                                 Feature  \
# 1752  Cocktail Pepperoni   Smoked Sausage Sticks   3...
# 1753                              Made with Real Cheese
# 1754  Chile & Limón Mix   Variety Pack   30 ct   Net...
# 1755  Variety Pack   1   Box with 72 Rolls   Flavore...
# ...

# %%
df.head(5)
# Out:
#         Sub Category     Price     Discount  \
# 0  Bakery & Desserts   $56.99   No Discount
# 1  Bakery & Desserts  $159.99   No Discount
# 2  Bakery & Desserts   $44.99   No Discount
# 3  Bakery & Desserts   $39.99   No Discount
# 4  Bakery & Desserts   $59.99   No Discount
#
#                                             Rating  \
# 0   Rated 4.3 out of 5 stars based on 265 reviews.
# 1       Rated 5 out of 5 stars based on 1 reviews.
# 2   Rated 4.1 out of 5 stars based on 441 reviews.
# 3  Rated 4.7 out of 5 stars based on 9459 reviews.
# 4   Rated 4.5 out of 5 stars based on 758 reviews.
#
#                                                Title Currency  \
# 0  David’s Cookies Mile High Peanut Butter Cake, ...        $
# 1  The Cake Bake Shop 8" Round Carrot Cake (16-22...        $
# 2  St Michel Madeleine, Classic French Sponge Cak...        $
# 3  David's Cookies Butter Pecan Meltaways 32 oz, ...        $
# 4  David’s Cookies Premier Chocolate Cake, 7.2 lb...        $
#
# ...

# %%
df.size
# Out:
# 14056

# %%
df.shape
# Out:
# (1757, 8)

# %%
df.columns
# Out:
# Index(['Sub Category', 'Price', 'Discount', 'Rating', 'Title', 'Currency',
#        'Feature', 'Product Description'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1757, step=1)

# %%
df.dtypes
# Out:
# Sub Category           object
# Price                  object
# Discount               object
# Rating                 object
# Title                  object
# Currency               object
# Feature                object
# Product Description    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1757 entries, 0 to 1756
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sub Category         1757 non-null   object
#  1   Price                1754 non-null   object
#  2   Discount             1757 non-null   object
#  3   Rating               682 non-null    object
#  4   Title                1757 non-null   object
#  5   Currency             1752 non-null   object
#  6   Feature              1739 non-null   object
#  7   Product Description  1715 non-null   object
# dtypes: object(8)
# memory usage: 109.9+ KB

# %%
df.describe()
# Out:
#        Sub Category    Price     Discount      Rating  \
# count          1757     1754         1757         682
# unique           19      184           42         483
# top          Snacks  $14.99   No Discount  No Reviews
# freq            293       81         1626          61
#
#                                                     Title Currency  \
# count                                                1757     1752
# unique                                               1484        1
# top     Ziploc Seal Top Freezer Bag, Gallon, 38-count,...        $
# freq                                                    4     1752
#
#                                                   Feature  \
# count                                                1739
# unique                                               1401
# top     Pick Your Arrival Date at Checkout   Gift Mess...
# freq                                                    7
#
#                                       Product Description
# ...

# %%
df.value_counts()
# Out:
# Sub Category       Price     Discount     Rating                                          Title                                                                                                             Currency  Feature                                                                                                                                                                                                                                                                      Product Description
# ...

# %%
df[5:11][['Title','Price']]
# Out:
#                                                 Title     Price
# 5   David's Cookies Mango & Strawberry Cheesecake ...   $59.99
# 6   La Grande Galette French Butter Cookies, 1.3 l...   $74.99
# 7   David's Cookies No Sugar Added Cheesecake & Ma...   $59.99
# 8       David's Cookies Brownie and Cookie Combo Pack   $29.99
# 9   The Cake Bake Shop 8" Round Chocolate Cake (16...  $159.99
# 10    David's Cookies 10" Rainbow Cake  (12 Servings)   $62.99

# %%
df.iloc[1699:1720]
# Out:
#      Sub Category    Price         Discount  \
# 1699       Snacks  $12.49       No Discount
# 1700       Snacks  $11.49   After $3.50 OFF
# 1701       Snacks  $15.99       No Discount
# 1702       Snacks  $17.99       No Discount
# 1703       Snacks  $28.99       No Discount
# 1704       Snacks  $17.99       No Discount
# 1705       Snacks   $9.99       No Discount
# 1706       Snacks   $9.49       No Discount
# 1707       Snacks  $17.99      After $4 OFF
# 1708       Snacks   $8.49       No Discount
# 1709       Snacks   $9.99       No Discount
# 1710       Snacks  $15.99       No Discount
# 1711       Snacks  $24.99       No Discount
# 1712       Snacks  $18.99       No Discount
# 1713       Snacks  $12.49       No Discount
# 1714       Snacks  $39.99       No Discount
# 1715       Snacks   $9.99       No Discount
# 1716       Snacks  $56.99       No Discount
# 1717       Snacks  $59.99       No Discount
# 1718       Snacks  $15.99       No Discount
# ...

# %%
df.loc[1699:1705]
# Out:
#      Sub Category    Price         Discount Rating  \
# 1699       Snacks  $12.49       No Discount    NaN
# 1700       Snacks  $11.49   After $3.50 OFF    NaN
# 1701       Snacks  $15.99       No Discount    NaN
# 1702       Snacks  $17.99       No Discount    NaN
# 1703       Snacks  $28.99       No Discount    NaN
# 1704       Snacks  $17.99       No Discount    NaN
# 1705       Snacks   $9.99       No Discount    NaN
#
#                                                   Title Currency  \
# 1699                  Ritz Crackers, 61.65 oz, 18 count        $
# 1700  Second Nature Trail Mix, Wholesome Medley, 1.5...        $
# 1701   Bobo's Oat Bites, Variety Pack, 1.3 oz, 24-count        $
# 1702  Cheez-It White Cheddar Baked Snack Cracker, 1....        $
# 1703  Slim Jim Smoked Snack Stick, Original, 0.28 oz...        $
# 1704  Lenny & Larry's The Complete Cookie, White Cho...        $
# 1705   Pocky Chocolate Biscuit Stick, 1.41 oz, 10-count        $
#
# ...

# %%
df[df['Price']==39.99]
# Out:
# Empty DataFrame
# Columns: [Sub Category, Price, Discount, Rating, Title, Currency, Feature, Product Description]
# Index: []

# %%
df.isnull().sum()
# Out:
# Sub Category              0
# Price                     3
# Discount                  0
# Rating                 1075
# Title                     0
# Currency                  5
# Feature                  18
# Product Description      42
# dtype: int64

# %%
df['Currency'].isnull().sum()
# Out:
# np.int64(5)

# %%
df['Currency']
# Out:
# 0       $
# 1       $
# 2       $
# 3       $
# 4       $
#        ..
# 1752    $
# 1753    $
# 1754    $
# 1755    $
# 1756    $
# Name: Currency, Length: 1757, dtype: object

# %%
for i in range(len(df)):
    if df.loc[i, 'Currency'] == '$':
        df.replace(['$'],[100],inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_9368\2087457291.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(['$'],[100],inplace=True)

# %%
df
# Out:
#            Sub Category     Price     Discount  \
# 0     Bakery & Desserts   $56.99   No Discount
# 1     Bakery & Desserts  $159.99   No Discount
# 2     Bakery & Desserts   $44.99   No Discount
# 3     Bakery & Desserts   $39.99   No Discount
# 4     Bakery & Desserts   $59.99   No Discount
# ...                 ...       ...          ...
# 1752             Snacks   $23.99   No Discount
# 1753             Snacks   $49.99   No Discount
# 1754             Snacks   $22.99   No Discount
# 1755             Snacks   $17.49   No Discount
# 1756             Snacks   $21.99   No Discount
#
#                                                Rating  \
# 0      Rated 4.3 out of 5 stars based on 265 reviews.
# 1          Rated 5 out of 5 stars based on 1 reviews.
# 2      Rated 4.1 out of 5 stars based on 441 reviews.
# 3     Rated 4.7 out of 5 stars based on 9459 reviews.
# 4      Rated 4.5 out of 5 stars based on 758 reviews.
# ...                                               ...
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1752    False
# 1753    False
# 1754    False
# 1755    False
# 1756    False
# Length: 1757, dtype: bool

# %%
df['Sub Category'].duplicated()
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1752     True
# 1753     True
# 1754     True
# 1755     True
# 1756     True
# Name: Sub Category, Length: 1757, dtype: bool

# %%
df['Sub Category'].drop_duplicates(inplace=True)

# %%
def change(data):
    return data['Currency'] + 100

# %%
df['Cleaned_Currency']= df.apply(change, axis = 1)

# %%
df
# Out:
#            Sub Category     Price     Discount  \
# 0     Bakery & Desserts   $56.99   No Discount
# 1     Bakery & Desserts  $159.99   No Discount
# 2     Bakery & Desserts   $44.99   No Discount
# 3     Bakery & Desserts   $39.99   No Discount
# 4     Bakery & Desserts   $59.99   No Discount
# ...                 ...       ...          ...
# 1752             Snacks   $23.99   No Discount
# 1753             Snacks   $49.99   No Discount
# 1754             Snacks   $22.99   No Discount
# 1755             Snacks   $17.49   No Discount
# 1756             Snacks   $21.99   No Discount
#
#                                                Rating  \
# 0      Rated 4.3 out of 5 stars based on 265 reviews.
# 1          Rated 5 out of 5 stars based on 1 reviews.
# 2      Rated 4.1 out of 5 stars based on 441 reviews.
# 3     Rated 4.7 out of 5 stars based on 9459 reviews.
# 4      Rated 4.5 out of 5 stars based on 758 reviews.
# ...                                               ...
# ...

# %%
df['Price'].astype(bool)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1752    True
# 1753    True
# 1754    True
# 1755    True
# 1756    True
# Name: Price, Length: 1757, dtype: bool

# %%
df['Sub Category'].str.upper()
# Out:
# 0       BAKERY & DESSERTS
# 1       BAKERY & DESSERTS
# 2       BAKERY & DESSERTS
# 3       BAKERY & DESSERTS
# 4       BAKERY & DESSERTS
#               ...
# 1752               SNACKS
# 1753               SNACKS
# 1754               SNACKS
# 1755               SNACKS
# 1756               SNACKS
# Name: Sub Category, Length: 1757, dtype: object

# %%
df['Rating'].str.contains('NAN', case = True)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1752      NaN
# 1753      NaN
# 1754      NaN
# 1755      NaN
# 1756      NaN
# Name: Rating, Length: 1757, dtype: object

# %%
df.groupby('Feature').sum()
# Out:
#                                                           Sub Category  \
# Feature
# "10" Four Layer Chocolate Cake\nCertified Koshe...   Bakery & Desserts
# "10"" Cheesecakes, 2-count\n1 Turtle Style, Cho...   Bakery & Desserts
# "10"" Peanut Butter Cake\nCertified Kosher OU-D...   Bakery & Desserts
# #1 Recommended Brand in America   Phosphate Free     Cleaning Supplies
# (1) 7 lbs Japanese A5 Grade Texas Clod Heart\nI...      Meat & Seafood
# ...                                                                ...
# Zero Scratch   S Wave   24 Sponges                   Cleaning Supplies
# Zero Ultra   24 fl oz Resealable Cans   12 Tota...   Beverages & Water
# Zero calorie sweetener   Kosher parve   Certifi...  Pantry & Dry Goods
# ​10 (2.4 oz.) Wellness Shots   25 (12 oz.) Cold...   Beverages & Water
# •100% Grass-fed Beef Jerky - 10 pack   No MSG o...              Snacks
#
#                                                    item_price      Discount  \
# Feature
# ...

# %%
df.sort_index()
# Out:
#            Sub Category item_price     Discount  \
# 0     Bakery & Desserts    $56.99   No Discount
# 1     Bakery & Desserts   $159.99   No Discount
# 2     Bakery & Desserts    $44.99   No Discount
# 3     Bakery & Desserts    $39.99   No Discount
# 4     Bakery & Desserts    $59.99   No Discount
# ...                 ...        ...          ...
# 1752             Snacks    $23.99   No Discount
# 1753             Snacks    $49.99   No Discount
# 1754             Snacks    $22.99   No Discount
# 1755             Snacks    $17.49   No Discount
# 1756             Snacks    $21.99   No Discount
#
#                                                Rating  \
# 0      Rated 4.3 out of 5 stars based on 265 reviews.
# 1          Rated 5 out of 5 stars based on 1 reviews.
# 2      Rated 4.1 out of 5 stars based on 441 reviews.
# 3     Rated 4.7 out of 5 stars based on 9459 reviews.
# 4      Rated 4.5 out of 5 stars based on 758 reviews.
# ...                                               ...
# ...

# %%
df['item_price'].reset_index()
# Out:
#       index item_price
# 0         0    $56.99
# 1         1   $159.99
# 2         2    $44.99
# 3         3    $39.99
# 4         4    $59.99
# ...     ...        ...
# 1752   1752    $23.99
# 1753   1753    $49.99
# 1754   1754    $22.99
# 1755   1755    $17.49
# 1756   1756    $21.99
#
# [1757 rows x 2 columns]

# %%
#concat()
#pd.concat([dataframe1,dataframe2)

# %%
df1=pd.read_csv('netflix_titles.csv')

# %%
df1
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
A=df1.loc[1999:2000]

# %%
A
# Out:
#      show_id   type                               title      director  \
# 1999   s2000  Movie  Hope Frozen: A Quest to Live Twice  Pailin Wedel
# 2000   s2001  Movie           Michael McIntyre: Showman    Chris Howe
#
#                   cast                  country          date_added  \
# 1999               NaN  Thailand, United States  September 15, 2020
# 2000  Michael McIntyre           United Kingdom  September 15, 2020
#
#       release_year rating duration                            listed_in  \
# 1999          2020  TV-PG   80 min  Documentaries, International Movies
# 2000          2020  TV-MA   63 min                      Stand-Up Comedy
#
#                                             description
# 1999  A Thai scientist and his family decide to cryo...
# 2000  Charming comic Michael McIntyre talks family, ...

# %%
B=df1.loc[7994:7999]

# %%
B
# Out:
#      show_id   type                                             title  \
# 7994   s7995  Movie                                 Shakti: The Power
# 7995   s7996  Movie                                          Shanghai
# 7996   s7997  Movie                                          Shararat
# 7997   s7998  Movie                                     Shark Busters
# 7998   s7999  Movie                                       Shark Night
# 7999   s8000  Movie  Shaurya: It Takes Courage to Make Right... Right
#
#               director                                               cast  \
# 7994    Krishna Vamshi  Karisma Kapoor, Nana Patekar, Sanjay Kapoor, S...
# 7995  Dibakar Banerjee  Emraan Hashmi, Abhay Deol, Prasenjit Chatterje...
# 7996    Gurudev Bhalla  Abhishek Bachchan, Hrishitaa Bhatt, Amrish Pur...
# 7997        Herman Yau  Danny Lee, Hui Siu-Hung, Lam Suet, Alfred Cheu...
# 7998    David R. Ellis  Sara Paxton, Dustin Milligan, Chris Carmack, K...
# ...

# %%
C=pd.concat([A,B])

# %%
C
# Out:
#      show_id   type                                             title  \
# 1999   s2000  Movie                Hope Frozen: A Quest to Live Twice
# 2000   s2001  Movie                         Michael McIntyre: Showman
# 7994   s7995  Movie                                 Shakti: The Power
# 7995   s7996  Movie                                          Shanghai
# 7996   s7997  Movie                                          Shararat
# 7997   s7998  Movie                                     Shark Busters
# 7998   s7999  Movie                                       Shark Night
# 7999   s8000  Movie  Shaurya: It Takes Courage to Make Right... Right
#
#               director                                               cast  \
# 1999      Pailin Wedel                                                NaN
# 2000        Chris Howe                                   Michael McIntyre
# 7994    Krishna Vamshi  Karisma Kapoor, Nana Patekar, Sanjay Kapoor, S...
# ...

# %%
 #merge()
#dataframe.merge(right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)

# %%
df2=pd.read_csv('Flipkart_mobile_brands_scraped_data.csv')

# %%
df2
# Out:
#        Brand      Model            Color Memory Storage  Rating  \
# 0       OPPO        A53  Moonlight Black   4 GB   64 GB     4.5
# 1       OPPO        A53       Mint Cream   4 GB   64 GB     4.5
# 2       OPPO        A53  Moonlight Black   6 GB  128 GB     4.3
# 3       OPPO        A53       Mint Cream   6 GB  128 GB     4.3
# 4       OPPO        A53   Electric Black   4 GB   64 GB     4.5
# ...      ...        ...              ...    ...     ...     ...
# 2642  Xiaomi  Redmi Y3          Bold Red   4 GB   64 GB     4.3
# 2643  Xiaomi  Redmi Y3      Elegant Blue   3 GB   32 GB     4.3
# 2644  Xiaomi  Redmi Y3      Elegant Blue   4 GB   64 GB     4.2
# 2645  Xiaomi  Redmi Y3       Prime Black   3 GB   32 GB     4.2
# 2646  Xiaomi  Redmi Y3       Prime Black   4 GB   64 GB     4.3
#
#       Selling Price  Original Price
# 0           11990.0         15990.0
# 1           11990.0         15990.0
# 2           13990.0         17990.0
# 3           13990.0         17990.0
# ...

# %%
df3=pd.read_csv('Balaji Fast Food Sales.csv')

# %%
df3
# Out:
#      order_id        date        item_name  item_type  item_price  quantity  \
# 0           1  07-03-2022         Aalopuri   Fastfood          20        13
# 1           2   8/23/2022          Vadapav   Fastfood          20        15
# 2           3  11/20/2022          Vadapav   Fastfood          20         1
# 3           4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4           5  10-02-2022  Sugarcane juice  Beverages          25         8
# ..        ...         ...              ...        ...         ...       ...
# 995       996   3/19/2023          Frankie   Fastfood          50        10
# 996       997   9/20/2022         Sandwich   Fastfood          60         7
# 997       998   1/26/2023         Sandwich   Fastfood          60        13
# 998       999   8/27/2022         Panipuri   Fastfood          20         5
# 999      1000   5/29/2022         Aalopuri   Fastfood          20         3
#
# ...

# %%
df3.rename(columns={'item_price':'Selling Price'},inplace=True)

# %%
df2.merge(df3,on='Selling Price',how='right')
# Out:
#     Brand Model Color Memory Storage  Rating  Selling Price  Original Price  \
# 0     NaN   NaN   NaN    NaN     NaN     NaN             20             NaN
# 1     NaN   NaN   NaN    NaN     NaN     NaN             20             NaN
# 2     NaN   NaN   NaN    NaN     NaN     NaN             20             NaN
# 3     NaN   NaN   NaN    NaN     NaN     NaN             25             NaN
# 4     NaN   NaN   NaN    NaN     NaN     NaN             25             NaN
# ..    ...   ...   ...    ...     ...     ...            ...             ...
# 995   NaN   NaN   NaN    NaN     NaN     NaN             50             NaN
# 996   NaN   NaN   NaN    NaN     NaN     NaN             60             NaN
# 997   NaN   NaN   NaN    NaN     NaN     NaN             60             NaN
# 998   NaN   NaN   NaN    NaN     NaN     NaN             20             NaN
# 999   NaN   NaN   NaN    NaN     NaN     NaN             20             NaN
#
# ...

# %%
#join()
#dataframe.join(other, on, how, lsuffix, rsuffix, sort)

# %%
      data1 = {
         'Name':['priti', 'renu', 'riya', 'gurleen','bhumi'],
        'Age':[27, 24, 22,18,19],}

# %%
df4=pd.read_csv('Employee_Salary_Dataset.csv')

# %%
df5=pd.DataFrame(data1)

# %%
newdf = df5.join(df4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 newdf = df5.join(df4)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10764, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10754     if how == "cross":
#   10755         return merge(
#   10756             self,
#   10757             other,
#    (...)  10762             validate=validate,
#   10763         )
# > 10764     return merge(
#   10765         self,
#   10766         other,
#   10767         left_on=on,
#   10768         how=how,
#   10769         left_index=on is None,
#   10770         right_index=True,
#   10771         suffixes=(lsuffix, rsuffix),
#   10772         sort=sort,
#   10773         validate=validate,
#   10774     )
#   10775 else:
#   10776     if on is not None:
#
# ...
