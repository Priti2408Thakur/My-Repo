# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\admin\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
df = pd.read_csv('Sample - Superstore.csv',encoding='latin1')

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.size
# Out:
# 209874

# %%
df.info
# Out:
# <bound method DataFrame.info of       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
df.value_counts()
# Out:
# Row ID  Order ID        Order Date  Ship Date   Ship Mode       Customer ID  Customer Name     Segment    Country        City             State       Postal Code  Region  Product ID       Category         Sub-Category  Product Name                                                               Sales     Quantity  Discount  Profit
# 1       CA-2016-152156  11/8/2016   11/11/2016  Second Class    CG-12520     Claire Gute       Consumer   United States  Henderson        Kentucky    42420        South   FUR-BO-10001798  Furniture        Bookcases     Bush Somerset Collection Bookcase                                          261.9600  2         0.00       41.9136     1
# ...

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[(df['Ship Date']==2/1/2015)]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['Ship Date'].value_counts()
# Out:
# Ship Date
# 12/16/2015    35
# 9/26/2017     34
# 11/21/2017    32
# 12/6/2017     32
# 9/6/2017      30
#               ..
# 2/19/2016      1
# 2/1/2015       1
# 8/25/2016      1
# 1/27/2014      1
# 1/23/2014      1
# Name: count, Length: 1334, dtype: int64

# %%
df['Category'].loc[5:20]
# Out:
# 5           Furniture
# 6     Office Supplies
# 7          Technology
# 8     Office Supplies
# 9     Office Supplies
# 10          Furniture
# 11         Technology
# 12    Office Supplies
# 13    Office Supplies
# 14    Office Supplies
# 15    Office Supplies
# 16    Office Supplies
# 17    Office Supplies
# 18    Office Supplies
# 19         Technology
# 20    Office Supplies
# Name: Category, dtype: object

# %%
df['Category'].iloc[5:20]
# Out:
# 5           Furniture
# 6     Office Supplies
# 7          Technology
# 8     Office Supplies
# 9     Office Supplies
# 10          Furniture
# 11         Technology
# 12    Office Supplies
# 13    Office Supplies
# 14    Office Supplies
# 15    Office Supplies
# 16    Office Supplies
# 17    Office Supplies
# 18    Office Supplies
# 19         Technology
# Name: Category, dtype: object

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])

# %%
df['Order Date']
# Out:
# 0      2016-11-08
# 1      2016-11-08
# 2      2016-06-12
# 3      2015-10-11
# 4      2015-10-11
#           ...
# 9989   2014-01-21
# 9990   2017-02-26
# 9991   2017-02-26
# 9992   2017-02-26
# 9993   2017-05-04
# Name: Order Date, Length: 9994, dtype: datetime64[ns]

# %%
df['Year']=df['Order Date'].dt.year

# %%
df['Year'].value_counts()
# Out:
# Year
# 2017    3312
# 2016    2587
# 2015    2102
# 2014    1993
# Name: count, dtype: int64

# %%
df.head(1)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08  11/11/2016  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...  South
#
#         Product ID   Category Sub-Category                       Product Name  \
# 0  FUR-BO-10001798  Furniture    Bookcases  Bush Somerset Collection Bookcase
#
#     Sales Quantity  Discount   Profit  Year
# 0  261.96        2       0.0  41.9136  2016
#
# [1 rows x 22 columns]

# %%
import matplotlib.pyplot as plt

# %%
 df.groupby('Category')[['Profit','Sales']].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
main = df.groupby('Category')[['Profit','Sales','Year']].sum()
main['Sales'].sort_values(ascending=False).plot(kind='pie')
# Out:
# <Axes: ylabel='Sales'>

# %%
main
# Out:
#                       Profit        Sales      Year
# Category
# Furniture         18451.2728  741999.7953   4275328
# Office Supplies  122490.8008  719047.0320  12146743
# Technology       145454.9481  836154.0330   3723057

# %%
main.values
# Out:
# array([[   18451.2728,   741999.7953,  4275328.    ],
#        [  122490.8008,   719047.032 , 12146743.    ],
#        [  145454.9481,   836154.033 ,  3723057.    ]])

# %%
main.index
# Out:
# Index(['Furniture', 'Office Supplies', 'Technology'], dtype='object', name='Category')

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,3,1)
plt.bar(main.index,main['Sales'])
plt.title('main one')

plt.subplot(3,1,2)
plt.plot(main.index,main['Profit'])
plt.title('main two')

plt.subplot(2,3,3)
plt.scatter(main.index,main['Year'])
plt.title('main three')
# Out:
# Text(0.5, 1.0, 'main three')
