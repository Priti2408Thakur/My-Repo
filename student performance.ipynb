# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\admin\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
df=pd.read_csv('StudentsPerformance.csv')

# %%
df
# Out:
#      gender         lunch parental level of education race/ethnicity  \
# 0    female      standard           bachelor's degree        group B
# 1    female      standard                some college        group C
# 2    female      standard             master's degree        group B
# 3      male  free/reduced          associate's degree        group A
# 4      male      standard                some college        group C
# ..      ...           ...                         ...            ...
# 995  female      standard             master's degree        group E
# 996    male  free/reduced                 high school        group C
# 997  female  free/reduced                 high school        group C
# 998  female      standard                some college        group D
# 999  female  free/reduced                some college        group D
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.groupby('race/ethnicity')['writing score'].max().sort_values()
# Out:
# race/ethnicity
# group B     96
# group A     97
# group C    100
# group D    100
# group E    100
# Name: writing score, dtype: int64

# %%
df.groupby('gender')[['math score','reading score','writing score']].mean()
# Out:
#         math score  reading score  writing score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
df[df[['math score','reading score','writing score']]>90].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df[(df['parental level of education']=="bachelor's degree")]
# Out:
#      gender         lunch parental level of education race/ethnicity  \
# 0    female      standard           bachelor's degree        group B
# 24     male  free/reduced           bachelor's degree        group D
# 27   female      standard           bachelor's degree        group C
# 60     male  free/reduced           bachelor's degree        group E
# 77     male      standard           bachelor's degree        group A
# ..      ...           ...                         ...            ...
# 916    male      standard           bachelor's degree        group E
# 933    male  free/reduced           bachelor's degree        group C
# 969  female      standard           bachelor's degree        group B
# 970  female      standard           bachelor's degree        group D
# 993  female  free/reduced           bachelor's degree        group D
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
new = df[['reading score','writing score']]

# %%
df['Average_score']=df['math score']+df['reading score']+df['writing score'] / 3

# %%
df
# Out:
#      gender         lunch parental level of education race/ethnicity  \
# 0    female      standard           bachelor's degree        group B
# 1    female      standard                some college        group C
# 2    female      standard             master's degree        group B
# 3      male  free/reduced          associate's degree        group A
# 4      male      standard                some college        group C
# ..      ...           ...                         ...            ...
# 995  female      standard             master's degree        group E
# 996    male  free/reduced                 high school        group C
# 997  female  free/reduced                 high school        group C
# 998  female      standard                some college        group D
# 999  female  free/reduced                some college        group D
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df
# Out:
#      gender         lunch parental level of education race/ethnicity  \
# 0    female      standard           bachelor's degree        group B
# 1    female      standard                some college        group C
# 2    female      standard             master's degree        group B
# 3      male  free/reduced          associate's degree        group A
# 4      male      standard                some college        group C
# ..      ...           ...                         ...            ...
# 995  female      standard             master's degree        group E
# 996    male  free/reduced                 high school        group C
# 997  female  free/reduced                 high school        group C
# 998  female      standard                some college        group D
# 999  female  free/reduced                some college        group D
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df.groupby('gender')['Average_score'].max()
# Out:
# gender
# female    233.333333
# male      233.333333
# Name: Average_score, dtype: float64

# %%
new
# Out:
#      reading score  writing score
# 0               72             74
# 1               90             88
# 2               95             93
# 3               57             44
# 4               78             75
# ..             ...            ...
# 995             99             95
# 996             55             55
# 997             71             65
# 998             78             77
# 999             86             86
#
# [1000 rows x 2 columns]

# %%
new.corr()
# Out:
#                reading score  writing score
# reading score       1.000000       0.954598
# writing score       0.954598       1.000000

# %%
df['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# gender                         0
# lunch                          0
# parental level of education    0
# race/ethnicity                 0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# Average_score                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.groupby('gender')['test preparation course'].value_counts()
# Out:
# gender  test preparation course
# female  none                       334
#         completed                  184
# male    none                       308
#         completed                  174
# Name: count, dtype: int64
