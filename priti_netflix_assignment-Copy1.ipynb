# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\admin\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
df=pd.read_csv('netflix_titles.csv')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # basic Exploration

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.head(15)
# Out:
#    show_id     type                                title  \
# 0       s1    Movie                 Dick Johnson Is Dead
# 1       s2  TV Show                        Blood & Water
# 2       s3  TV Show                            Ganglands
# 3       s4  TV Show                Jailbirds New Orleans
# 4       s5  TV Show                         Kota Factory
# 5       s6  TV Show                        Midnight Mass
# 6       s7    Movie     My Little Pony: A New Generation
# 7       s8    Movie                              Sankofa
# 8       s9  TV Show        The Great British Baking Show
# 9      s10    Movie                         The Starling
# 10     s11  TV Show  Vendetta: Truth, Lies and The Mafia
# 11     s12  TV Show                     Bangkok Breaking
# 12     s13    Movie                         Je Suis Karl
# 13     s14    Movie     Confessions of an Invisible Girl
# 14     s15  TV Show      Crime Stories: India Detectives
#
#                          director  \
# ...

# %%
df.tail(5)
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.shape[1]
# Out:
# 12

# %%
df.shape[0]
# Out:
# 8807

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df['country'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       United States
# 1        South Africa
# 2                 NaN
# 3                 NaN
# 4               India
#             ...
# 8802    United States
# 8803              NaN
# 8804    United States
# 8805    United States
# 8806            India
# Name: country, Length: 8807, dtype: object>

# %% [markdown]
# # Data selection & slicing

# %%
df[df['release_year']>2018]
# Out:
#      show_id     type                        title             director  \
# 0         s1    Movie         Dick Johnson Is Dead      Kirsten Johnson
# 1         s2  TV Show                Blood & Water                  NaN
# 2         s3  TV Show                    Ganglands      Julien Leclercq
# 3         s4  TV Show        Jailbirds New Orleans                  NaN
# 4         s5  TV Show                 Kota Factory                  NaN
# ...      ...      ...                          ...                  ...
# 8516   s8517    Movie    The Spy Who Fell to Earth      Thomas Meadmore
# 8631   s8632    Movie  Trixie Mattel: Moving Parts  Nicholas Zeig-Owens
# 8718   s8719    Movie       Westside vs. the World        Michael Fahey
# 8752   s8753    Movie                     Wish Man          Theo Davies
# 8756   s8757    Movie                    Woodstock        Barak Goodman
#
#                                                    cast         country  \
# ...

# %%
df.iloc[3056:3061,5:12]
# Out:
#                          country       date_added  release_year rating  \
# 3056                         NaN  January 1, 2020          2019  TV-Y7
# 3057               United States  January 1, 2020          2007   TV-Y
# 3058  United States, South Korea  January 1, 2020          2008  TV-Y7
# 3059  South Korea, United States  January 1, 2020          2009      G
# 3060                       India  January 1, 2020          2020  TV-MA
#
#       duration                                       listed_in  \
# 3056  1 Season                                        Kids' TV
# 3057    78 min              Children & Family Movies, Comedies
# 3058    79 min              Children & Family Movies, Comedies
# 3059    78 min              Children & Family Movies, Comedies
# 3060   145 min  Horror Movies, International Movies, Thrillers
#
#                                             description
# 3056  From kung fu battles to run-ins with bandits, ...
# ...

# %%
df.loc[1011:1015]
# Out:
#      show_id     type                     title            director  \
# 1011   s1012    Movie              Free to Play                 NaN
# 1012   s1013  TV Show  Luis Miguel - The Series                 NaN
# 1013   s1014    Movie               Miss Sloane         John Madden
# 1014   s1015  TV Show                  PJ Masks                 NaN
# 1015   s1016    Movie               American Me  Edward James Olmos
#
#                                                    cast  \
# 1011                                                NaN
# 1012  Diego Boneta, Juan Pablo Zurita, Camila Sodi, ...
# 1013  Jessica Chastain, Mark Strong, Gugu Mbatha-Raw...
# 1014      Jacob Ewaniuk, Kyle Breitkopf, Addison Holley
# 1015  Edward James Olmos, William Forsythe, Pepe Ser...
#
#                                             country      date_added  \
# 1011                                  United States  April 19, 2021
# 1012                                         Mexico  April 19, 2021
# ...

# %% [markdown]
# # Data cleaning

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
data = df['director'].isnull()

# %%
data
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 8802    False
# 8803     True
# 8804    False
# 8805    False
# 8806    False
# Name: director, Length: 8807, dtype: bool

# %%
df.notnull()
# Out:
#       show_id  type  title  director   cast  country  date_added  \
# 0        True  True   True      True  False     True        True
# 1        True  True   True     False   True     True        True
# 2        True  True   True      True   True    False        True
# 3        True  True   True     False  False    False        True
# 4        True  True   True     False   True     True        True
# ...       ...   ...    ...       ...    ...      ...         ...
# 8802     True  True   True      True   True     True        True
# 8803     True  True   True     False  False    False        True
# 8804     True  True   True      True   True     True        True
# 8805     True  True   True      True   True     True        True
# 8806     True  True   True      True   True     True        True
#
#       release_year  rating  duration  listed_in  description
# 0             True    True      True       True         True
# 1             True    True      True       True         True
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(4307)

# %%
df.size
# Out:
# 105684

# %%
df.fillna('Panda',inplace=True)

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
df[df['release_year'].duplicated()]
# Out:
#      show_id     type                             title  \
# 2         s3  TV Show                         Ganglands
# 3         s4  TV Show             Jailbirds New Orleans
# 4         s5  TV Show                      Kota Factory
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# ...      ...      ...                               ...
# 8802   s8803    Movie                            Zodiac
# 8803   s8804  TV Show                       Zombie Dumb
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 2                   Julien Leclercq
# 3                             Panda
# 4                             Panda
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# ...                             ...
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.notnull().sum()
# Out:
# show_id         8807
# type            8807
# title           8807
# director        8807
# cast            8807
# country         8807
# date_added      8807
# release_year    8807
# rating          8807
# duration        8807
# listed_in       8807
# description     8807
# dtype: int64

# %%
df['rating'].notnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 8802    True
# 8803    True
# 8804    True
# 8805    True
# 8806    True
# Name: rating, Length: 8807, dtype: bool

# %%
df.rename(columns={'date_added':'release_date'})
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water            Panda
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans            Panda
# 4         s5  TV Show           Kota Factory            Panda
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb            Panda
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                 Panda  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.replace(['TV-MA'],['Mature Audience'],inplace=True)

# %%
(df.isnull().sum().sum() / df.size)*100
# Out:
# np.float64(0.0)

# %%
df['rating'].dropna
# Out:
# <bound method Series.dropna of 0                 PG-13
# 1       Mature Audience
# 2       Mature Audience
# 3       Mature Audience
# 4       Mature Audience
#              ...
# 8802                  R
# 8803              TV-Y7
# 8804                  R
# 8805                 PG
# 8806              TV-14
# Name: rating, Length: 8807, dtype: object>

# %%
df.to_csv('netflix_cleaned_data')
